# %%
#Mod 21, Iteration 1

import uproot
import numpy as np
import matplotlib.pyplot as plt


root_pre = "PS_16_FNL-10021_2025-12-02_04h37m52s_-33C_PSfullTest_v6-22.root"
root_post = (
    "/home/ekimrey/QPT_before_irradiation/"
    "post_irradiation_for_Emerson/"
    "TrackerHistos/TrackerHistos_42.root"
)


def read_th2(root_file, path):
    with uproot.open(root_file) as f:
        values, _, _ = f[path].to_numpy(flow=False)
    return np.array(values)


def make_pre_histpath(hybrid, chip):
    return (
        f"Detector/Board_0/OpticalGroup_1/Hybrid_{hybrid}/MPA_{chip}/"
        f"D_B(0)_O(1)_H({hybrid})_2DChannelNoise_Chip({chip});1"
    )


def make_post_histpath(hybrid, chip):
    return (
        f"Iteration_1_PSfullTest_2026-03-12_17-23-21/"
        f"Detector/Board_0/OpticalGroup_2/Hybrid_{hybrid}/MPA_{chip}/"
        f"D_B(0)_O(2)_H({hybrid})_2DChannelNoise_Chip({chip});1"
    )


labels = []

for pre_hybrid, post_hybrid in zip([2,3],[4,5]):
    for chip in range(8,16):

        labels.append(f"H{pre_hybrid}-C{chip}")

        values_pre = read_th2(
            root_pre,
            make_pre_histpath(pre_hybrid, chip))

        values_post = read_th2(
            root_post,
            make_post_histpath(post_hybrid, chip)
        )

        print(f"\nH{pre_hybrid}-C{chip}")

        plt.figure(figsize=(7,5))
        
        bins = np.linspace(0, 6, 100)
        
        plt.hist(values_pre.ravel(),
                 bins=bins,
                 histtype="step",
                 linewidth=2,
                 label="Pre")
        
        plt.hist(values_post.ravel(),
            bins=bins,
            histtype="step",
            linewidth=2,
            label = "Post")

        plt.xlabel("Noise")
        plt.ylabel("Pixels")
        plt.title(f"Module 21 Iteration 1 Hybrid {pre_hybrid}/{post_hybrid} Chip {chip}")

        plt.legend()
        plt.tight_layout()
        plt.show()
# Out:
# H2-C8
# H2-C9
# H2-C10
# H2-C11
# H2-C12
# H2-C13
# H2-C14
# H2-C15
# H3-C8
# H3-C9
# H3-C10
# H3-C11
# H3-C12
# H3-C13
# H3-C14
# H3-C15

# %%
#Mod 21, Iteration 3

def make_post_histpath(hybrid, chip):
    return (
        f"Iteration_3_PSfullTest_2026-03-13_08-45-57/"
        f"Detector/Board_0/OpticalGroup_2/Hybrid_{hybrid}/MPA_{chip}/"
        f"D_B(0)_O(2)_H({hybrid})_2DChannelNoise_Chip({chip});1"
    )


labels = []

for pre_hybrid, post_hybrid in zip([2,3],[4,5]):
    for chip in range(8,16):

        labels.append(f"H{pre_hybrid}-C{chip}")

        values_pre = read_th2(
            root_pre,
            make_pre_histpath(pre_hybrid, chip))

        values_post = read_th2(
            root_post,
            make_post_histpath(post_hybrid, chip)
        )

        print(f"\nH{pre_hybrid}-C{chip}")

        plt.figure(figsize=(7,5))

        bins = np.linspace(0, 6, 100)

        plt.hist(values_pre.ravel(),
                 bins=bins,
                 histtype="step",
                 linewidth=2,
                 label="Pre")
        
        plt.hist(values_post.ravel(),
            bins=bins,
            histtype="step",
            linewidth=2,
            label = "Post")

        plt.xlabel("Noise")
        plt.ylabel("Pixels")
        plt.title(f"Module 21 Iteration 3 Hybrid {pre_hybrid}/{post_hybrid} Chip {chip}")

        plt.legend()
        plt.tight_layout()
        plt.show()
# Out:
# H2-C8
# H2-C9
# H2-C10
# H2-C11
# H2-C12
# H2-C13
# H2-C14
# H2-C15
# H3-C8
# H3-C9
# H3-C10
# H3-C11
# H3-C12
# H3-C13
# H3-C14
# H3-C15

# %%
#Mod 35, Iteration 1

root_pre = "PS_16_FNL-10035_2025-12-02_04h37m52s_-33C_PSfullTest_v6-22.root"

def make_pre_histpath(hybrid, chip):
    return (
        f"Detector/Board_0/OpticalGroup_5/Hybrid_{hybrid}/MPA_{chip}/"
        f"D_B(0)_O(5)_H({hybrid})_2DChannelNoise_Chip({chip});1"
    )


def make_post_histpath(hybrid, chip):
    return (
        f"Iteration_1_PSfullTest_2026-03-12_17-23-21/"
        f"Detector/Board_0/OpticalGroup_1/Hybrid_{hybrid}/MPA_{chip}/"
        f"D_B(0)_O(1)_H({hybrid})_2DChannelNoise_Chip({chip});1"
    )


labels = []

for pre_hybrid, post_hybrid in zip([10,11],[2,3]):
    for chip in range(8,16):

        labels.append(f"H{pre_hybrid}-C{chip}")

        values_pre = read_th2(
            root_pre,
            make_pre_histpath(pre_hybrid, chip))

        values_post = read_th2(
            root_post,
            make_post_histpath(post_hybrid, chip)
        )

        print(f"\nH{pre_hybrid}-C{chip}")

        plt.figure(figsize=(7,5))

        bins = np.linspace(0, 6, 100)

        plt.hist(values_pre.ravel(),
                 bins=bins,
                 histtype="step",
                 linewidth=2,
                 label="Pre")
        
        plt.hist(values_post.ravel(),
            bins=bins,
            histtype="step",
            linewidth=2,
            label = "Post")

        plt.xlabel("Noise")
        plt.ylabel("Pixels")
        plt.title(f"Module 35 Iteration 1 Hybrid {pre_hybrid}/{post_hybrid} Chip {chip}")

        plt.legend()
        plt.tight_layout()
        plt.show()
# Out:
# H10-C8
# H10-C9
# H10-C10
# H10-C11
# H10-C12
# H10-C13
# H10-C14
# H10-C15
# H11-C8
# H11-C9
# H11-C10
# H11-C11
# H11-C12
# H11-C13
# H11-C14
# H11-C15

# %%
#Mod 35, Iteration 3

def make_post_histpath(hybrid, chip):
    return (
        f"Iteration_3_PSfullTest_2026-03-13_08-45-57/"
        f"Detector/Board_0/OpticalGroup_1/Hybrid_{hybrid}/MPA_{chip}/"
        f"D_B(0)_O(1)_H({hybrid})_2DChannelNoise_Chip({chip});1"
    )


labels = []

for pre_hybrid, post_hybrid in zip([10,11],[2,3]):
    for chip in range(8,16):

        labels.append(f"H{pre_hybrid}-C{chip}")

        values_pre = read_th2(
            root_pre,
            make_pre_histpath(pre_hybrid, chip))

        values_post = read_th2(
            root_post,
            make_post_histpath(post_hybrid, chip)
        )

        print(f"\nH{pre_hybrid}-C{chip}")

        plt.figure(figsize=(7,5))

        bins = np.linspace(0, 6, 100)

        plt.hist(values_pre.ravel(),
                 bins=bins,
                 histtype="step",
                 linewidth=2,
                 label="Pre")
        
        plt.hist(values_post.ravel(),
            bins=bins,
            histtype="step",
            linewidth=2,
            label = "Post")

        plt.xlabel("Noise")
        plt.ylabel("Pixels")
        plt.title(f"Module 35 Iteration 3 Hybrid {pre_hybrid}/{post_hybrid} Chip {chip}")

        plt.legend()
        plt.tight_layout()
        plt.show()
# Out:
# H10-C8
# H10-C9
# H10-C10
# H10-C11
# H10-C12
# H10-C13
# H10-C14
# H10-C15
# H11-C8
# H11-C9
# H11-C10
# H11-C11
# H11-C12
# H11-C13
# H11-C14
# H11-C15
